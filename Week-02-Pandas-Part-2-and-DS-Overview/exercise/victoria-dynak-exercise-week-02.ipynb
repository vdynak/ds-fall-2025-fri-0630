# %% [markdown]
# # Fall 2024 Data Science Track: Week 2 - Data Cleaning Exercise

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need the standard stuff: `pandas` and `numpy`.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import here.
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the following data sets:
#
# * `food_coded.csv`: [Food choices](https://www.kaggle.com/datasets/borapajo/food-choices?select=food_coded.csv) from Kaggle
# * `Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv`: [Ask A Manager Salary Survey 2021 (Responses)](https://docs.google.com/spreadsheets/d/1IPS5dBSGtwYVbjsfbaMCYIWnOuRmJcbequohNxCyGVw/view?&gid=1625408792) as *Tab Separated Values (.tsv)* from Google Docs
#
# Each one poses different challenges. But you’ll―of course―overcome them with what you learned in class! 😉

# %% [markdown]
# ## Food Choices Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Food choices data set into a variable (e.g., df_food).

food_data_set_path = '/workspaces/ds-fall-2025-fri-0630/Week-02-Pandas-Part-2-and-DS-Overview/data/food_coded.csv'

df_food = pd.read_csv(food_data_set_path)

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. (lol kidding)
df_food.shape
# Out:
# (125, 61)

# %% [markdown]
# What are the columns and their types in this data set?

# %%
# Show the column names and their types.
# There are one of two ways to do this depending on how many details you want.
df_food.dtypes
#If you don't want the output to be truncated.
#for col, dtype in df_food.dtypes.items():
#    print(col, ":", dtype)
# Out:
# GPA                  object
# Gender                int64
# breakfast             int64
# calories_chicken      int64
# calories_day        float64
#                      ...
# type_sports          object
# veggies_day           int64
# vitamins              int64
# waffle_calories       int64
# weight               object
# Length: 61, dtype: object

# %% [markdown]
# ### Clean the Data
#
# Perhaps we’d like to know more another day, but the team is really interested in just the relationship between calories (`calories_day`) and weight. …and maybe gender.

# %% [markdown]
# Can you remove the other columns?

# %%
# Remove ‘em.
df_food = df_food[["calories_day", "weight", "Gender"]]

# %% [markdown]
# What about `NaN`s? How many are there?

# %%
# Count ‘em.
per_col = df_food.isna().sum()
total_nans = df_food.isna().sum().sum()
print(per_col)
print("Total number of NaN's: ", total_nans)
# Out:
# calories_day    19
# weight           2
# Gender           0
# dtype: int64
# Total number of NaN's:  21

# %% [markdown]
# We gotta remove those `NaN`s―the entire row.

# %%
# Drop ‘em.
df_food = df_food.dropna()
df_food.isna().sum()
# Out:
# calories_day    0
# weight          0
# Gender          0
# dtype: int64

# %% [markdown]
# But what about the weird non-numeric values in the column obviously meant for numeric data?
#
# Notice the data type of that column from when you got the types of all the columns?
#
# If only we could convert the column to a numeric type and drop the rows with invalid values. 🤔

# %%
# Fix that.
#df_food.head()
df_food["weight"] = pd.to_numeric(df_food["weight"], errors = "coerce")
df_food = df_food.dropna(subset=["weight"])
df_food.head()
#df_food["weight"].dtype
# Out:
#    calories_day  weight  Gender
# 1           3.0   155.0       1
# 4           2.0   190.0       1
# 5           3.0   190.0       1
# 6           3.0   180.0       2
# 7           3.0   137.0       1

# %% [markdown]
# Now this data seems reasonably clean for our purposes! 😁
#
# Let’s save it somewhere to be shipped off to another teammate. 💾

# %%
# Savey save!
save_path = "/workspaces/ds-fall-2025-fri-0630/Week-02-Pandas-Part-2-and-DS-Overview/data/food_cleaned.csv"
df_food.to_csv(save_path, index=False)

# %% [markdown]
# ## Ask a Manager Salary Survey 2021 (Responses) Data Set

# %% [markdown]
# ### Load the Data

# %%
# Load the Ask A Manager Salary Survey 2021 (Responses) data set into a variable (e.g., df_salary).
manager_data_set_path = '/workspaces/ds-fall-2025-fri-0630/Week-02-Pandas-Part-2-and-DS-Overview/data/manager_survey_2021.tsv'
df_manager = pd.read_csv(manager_data_set_path, sep="\t")

# %% [markdown]
# Was that hard? 🙃

# %% [markdown]
# #### rename the file to something that is better for all systems.
# * No spaces in filename (can use '_')
# * all lower case

# %%
#old_path = "/workspaces/ds-fall-2025-fri-0630/Week-02-Pandas-Part-2-and-DS-Overview/data/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.tsv"
#new_path = "/workspaces/ds-fall-2025-fri-0630/Week-02-Pandas-Part-2-and-DS-Overview/data/manager_survey_2021.tsv"
#os.rename(old_path, new_path)

# %%
#df_manager = pd.read_csv(new_path, sep="\t")

# %% [markdown]
# ### Explore
#
# You know the drill.

# %% [markdown]
# How much data did you just load?

# %%
# Count by hand. I’m dead serious.
df_manager.shape
# Out:
# (28062, 18)

# %% [markdown]
# What are the columns and their types?

# %%
# Show the column names and their types.
df_manager.dtypes
for col, dtype in df_manager.dtypes.items():
    print(col, ":", dtype)
# Out:
# Timestamp : object
# How old are you? : object
# What industry do you work in? : object
# Job title : object
# If your job title needs additional context, please clarify here: : object
# What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.) : object
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits. : float64
# Please indicate the currency : object
# If "Other," please indicate the currency here:  : object
# If your income needs additional context, please provide it here: : object
# What country do you work in? : object
# If you're in the U.S., what state do you work in? : object
# What city do you work in? : object
# ...

# %% [markdown]
# Oh… Ugh! Give these columns easier names to work with first. 🙄

# %%
# Rename ‘em.
# Non-binding suggestions: timestamp, age, industry, title, title_context, salary, additional_compensation, currency, other_currency, salary_context, country, state, city, total_yoe, field_yoe, highest_education_completed	gender, race
rename_dict = {
    "Timestamp": "timestamp",
    "How old are you?": "age",
    "What industry do you work in?": "industry",
    "Job title": "title",
    "If your job title needs additional context, please clarify here:": "title_context",
    "What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)": "salary",
    "How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.": "additional_compensation",
    "Please indicate the currency": "currency",
    "If \"Other,\" please indicate the currency here:": "other_currency",
    "If your income needs additional context, please provide it here:": "salary_context",
    "What country do you work in?": "country",
    "If you're in the U.S., what state do you work in?": "state",
    "What city do you work in?": "city",
    "How many years of professional work experience do you have overall?": "total_yoe",
    "How many years of professional work experience do you have in your field?": "field_yoe",
    "What is your highest level of education completed?": "highest_education_completed",
    "What is your gender?": "gender",
    "What is your race? (Choose all that apply.)": "race"
}
#"If \"Other,\" please, added this special format to ensure the quotes are caught.
df_manager = df_manager.rename(columns=rename_dict)
df_manager.columns.tolist()
# Out:
# ['timestamp',
#  'age',
#  'industry',
#  'title',
#  'title_context',
#  'salary',
#  'additional_compensation',
#  'currency',
#  'If "Other," please indicate the currency here: ',
#  'salary_context',
#  'country',
#  'state',
#  'city',
#  'total_yoe',
#  'field_yoe',
#  'highest_education_completed',
#  'gender',
#  'race']

# %% [markdown]
# It’s a lot, and that should not have been easy. 😏

# %% [markdown]
# You’re going to have a gander at the computing/tech subset first because thats *your* industry. But first, what value corresponds to that `industry`?

# %%
# List the unique industries and a count of their instances.
df_manager["industry"].value_counts()
# Out:
# industry
# Computing or Tech                        4699
# Education (Higher Education)             2464
# Nonprofits                               2419
# Health care                              1896
# Government and Public Administration     1889
#                                          ...
# Warehousing                                 1
# Education (Early Childhood Education)       1
# SAAS                                        1
# Health and Safety                           1
# Aerospace Manufacturing                     1
# Name: count, Length: 1219, dtype: int64

# %% [markdown]
# That value among the top 5 is what you’re looking for innit? Filter out all the rows not in that industry and save it into a new dataframe.

# %%
# Filtery filter. (Save it to a new variable, df_salary_tech.)
df_salary_tech = df_manager[df_manager["industry"] == "Computing or Tech"]

# %% [markdown]
# Do a sanity check to make sure that the only values you kept are the one you are filtered for.

# %%
# Sanity Check 
df_salary_tech.head(30)
# Out:
#               timestamp    age           industry  \
# 1    4/27/2021 11:02:22  25-34  Computing or Tech
# 8    4/27/2021 11:03:01  45-54  Computing or Tech
# 43   4/27/2021 11:04:04  25-34  Computing or Tech
# 44   4/27/2021 11:04:04  25-34  Computing or Tech
# 46   4/27/2021 11:04:07  35-44  Computing or Tech
# 47   4/27/2021 11:04:09  35-44  Computing or Tech
# 53   4/27/2021 11:04:19  35-44  Computing or Tech
# 68   4/27/2021 11:04:36  25-34  Computing or Tech
# 74   4/27/2021 11:04:41  35-44  Computing or Tech
# 79   4/27/2021 11:04:49  35-44  Computing or Tech
# 89   4/27/2021 11:05:04  45-54  Computing or Tech
# 95   4/27/2021 11:05:08  45-54  Computing or Tech
# 99   4/27/2021 11:05:08  55-64  Computing or Tech
# 109  4/27/2021 11:05:21  25-34  Computing or Tech
# 114  4/27/2021 11:05:25  25-34  Computing or Tech
# 132  4/27/2021 11:05:46  35-44  Computing or Tech
# 159  4/27/2021 11:06:05  25-34  Computing or Tech
# 173  4/27/2021 11:06:13  45-54  Computing or Tech
# ...

# %% [markdown]
# We are very interested in salary figures. But how many dollars 💵 is a euro 💶 or a pound 💷? That sounds like a problem for another day. 🫠
#
# For now, let’s just look at U.S. dollars (`'USD'`).

# %%
# Filtery filter for just the jobs that pay in USD!
df_salary_usd = df_salary_tech[df_salary_tech["currency"] == "USD"]
df_salary_usd.head()
# Out:
#              timestamp    age           industry                        title  \
# 8   4/27/2021 11:03:01  45-54  Computing or Tech              Systems Analyst
# 43  4/27/2021 11:04:04  25-34  Computing or Tech  Principal Software Engineer
# 44  4/27/2021 11:04:04  25-34  Computing or Tech         Intelligence Analyst
# 46  4/27/2021 11:04:07  35-44  Computing or Tech             Mobile developer
# 47  4/27/2021 11:04:09  35-44  Computing or Tech      Product Design Director
#
#                    title_context   salary  additional_compensation currency  \
# 8   Data developer/ETL Developer  112,000                  10000.0      USD
# 43                           NaN  187,500                   5000.0      USD
# 44                           NaN  110,000                  20000.0      USD
# 46                           NaN  144,600                   2500.0      USD
# 47                           NaN  200,850                  40000.0      USD
#
# ...

# %% [markdown]
# What we really want know is how each U.S. city pays in tech. What value in `country` represents the United States of America?

# %%
# We did filter for USD, so if we do a count of each unique country in descending count order, the relevant value(s) should show up at the top.
df_salary_usd["country"].value_counts()
# Out:
# country
# United States               1576
# USA                         1222
# US                           412
# U.S.                         108
# United States of America      90
#                             ...
# Ghana                          1
# Nigeria                        1
# ss                             1
# Nigeria                        1
# Burma                          1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### Clean the Data
#
# Well, we can’t get our answers with what we currently have, so you’ll have to make some changes.

# %% [markdown]
# Let’s not worry about anything below the first 5 values for now. Convert the top 5 to a single canonical value―say, `'US'`, which is nice and short.

# %%
# Replace them all with 'US'.
us_spellings = ["United States", "USA", "US", "U.S.", "United States of America"]
df_salary_usd["country"] = df_salary_usd["country"].replace(us_spellings, "US")
# Out:
# /tmp/ipykernel_4937/2328419969.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_usd["country"] = df_salary_usd["country"].replace(us_spellings, "US")

# %% [markdown]
# Have a look at the count of each unique country again now.

# %%
# Count again.
df_salary_usd["country"].value_counts().head(10)
# Out:
# country
# US                3408
# United States       68
# Usa                 59
# USA                 56
# usa                 28
# United states       23
# united states       14
# Us                  12
# us                   9
# U.S.A.               7
# Name: count, dtype: int64

# %% [markdown]
# Did you notice anything interesting?

# %%
# BONUS CREDIT: resolve [most of] those anomalous cases too without exhaustively taking every variant literally into account.
df_salary_usd["country"] = df_salary_usd["country"].str.lower().str.strip()
us_spellings = ["united states", "united states of america", "u.s.a", "unite states", "united state of america", "unitedstates", "unitedstates", "usa", "u.s.", "u.s.a.", "u.s", "us", "us of a"]
df_salary_usd["country"] = df_salary_usd["country"].replace(us_spellings, "us")
# Out:
# /tmp/ipykernel_4937/534749516.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_usd["country"] = df_salary_usd["country"].str.lower().str.strip()
# /tmp/ipykernel_4937/534749516.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salary_usd["country"] = df_salary_usd["country"].replace(us_spellings, "us")

# %%
# BONUS CREDIT: if you’ve resolved it, let’s see how well you did by counting the number of instances of each unique value.
df_salary_usd["country"].value_counts().head(10)
# Out:
# country
# us                3714
# canada               5
# israel               5
# australia            2
# united kingdom       2
# france               2
# poland               2
# brazil               2
# singapore            2
# spain                2
# Name: count, dtype: int64

# %% [markdown]
# It’s looking good so far. Let’s find out the minimum, mean, and maximum (in that order) salary by state, sorted by the mean in descending order.

# %%
# Find the minimum, mean, and maximum salary in USD by U.S. state.
df_us = df_salary_usd[df_salary_usd["country"] == "US"].copy()
grouped = df_us.groupby("state")["salary"]
stats = grouped.agg(["min", "mean", "max"])
state_salary_stats = stats.sort_values("mean", ascending=False)
print(state_salary_stats.head(10))
# Out:
# Empty DataFrame
# Columns: [min, mean, max]
# Index: []

# %% [markdown]
# Well, pooh! We forgot that `salary` isn’t numeric. Something wrong must be fixed.

# %%
# Fix it.
#adding one line of code:
df_salary_usd["salary"] = pd.to_numeric(df_salary_usd["salary"], errors="coerce")
df_us = df_salary_usd[df_salary_usd["country"] == "us"].copy()
grouped = df_us.groupby("state")["salary"]
stats = grouped.agg(["min", "mean", "max"])
state_salary_stats = stats.sort_values("mean", ascending=False)
print(state_salary_stats.head(10))
# Out:
#                                   min           mean        max
# state
# Michigan, Texas, Washington  340000.0  340000.000000   340000.0
# Florida                       28800.0  210711.000000  2600000.0
# California, Oregon           200000.0  200000.000000   200000.0
# California, Colorado         176000.0  176000.000000   176000.0
# Delaware                     169000.0  169000.000000   169000.0
# Connecticut                   68000.0  161610.000000   270000.0
# California                        0.0  153757.140449   520000.0
# New York                      14000.0  146594.112150   590000.0
# Wisconsin                         1.0  145806.888889   920000.0
# District of Columbia          59000.0  142923.076923   200000.0
# /tmp/ipykernel_4937/3095899469.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# Let’s try that again.

# %%
# Try it again. Yeah!
#California, Oregon example
df_us = df_us.assign(state=df_us["state"].str.split(r",\s*")).explode("state")
df_us["state"] = df_us["state"].str.strip()
grouped = df_us.groupby("state")["salary"]
stats = grouped.agg(["min", "mean", "max"])
state_salary_stats = stats.sort_values("mean", ascending=False)
print(state_salary_stats.head(10))
# Out:
#                            min           mean        max
# state
# Florida                28800.0  210711.000000  2600000.0
# Delaware              169000.0  169000.000000   169000.0
# Connecticut            68000.0  161610.000000   270000.0
# California                 0.0  153736.303867   520000.0
# New York               14000.0  146427.247706   590000.0
# Wisconsin                  1.0  145806.888889   920000.0
# District of Columbia   59000.0  140514.285714   200000.0
# Washington                72.0  139398.945946   340000.0
# Ohio                   42000.0  137066.666667   954000.0
# New Jersey             67500.0  126153.846154   192000.0

# %% [markdown]
# That did the trick! Now let’s narrow this to data 2021 and 2022 just because (lel). *(Hint: that timestamp column may not be a temporal type right now.)*

# %%
# Filter the data to within 2021, 2022, or 2023, saving the DataFrame to a new variable, and generate the summary again.
df_reqyears = df_salary_usd.copy()
df_reqyears["timestamp"] = pd.to_datetime(df_reqyears["timestamp"], errors="coerce")
df_reqyears = df_reqyears[df_reqyears["timestamp"].dt.year.isin([2021, 2022, 2023])]
df_us = df_reqyears[df_reqyears["country"].str.strip() == "us"][["state", "salary"]].copy()
df_us = df_us.assign(state=df_us["state"].str.split(r",\s*")).explode("state")
df_us["state"] = df_us["state"].str.strip()
grouped = df_us.groupby("state")["salary"]
stats = grouped.agg(["min", "mean", "max"])
state_salary_stats = stats.sort_values("mean", ascending=False)
print(state_salary_stats.head(10))
print(df_reqyears["timestamp"].dt.year.unique())
# Out:
#                            min           mean       max
# state
# Delaware              169000.0  169000.000000  169000.0
# Connecticut            68000.0  161610.000000  270000.0
# California                 0.0  154201.505556  520000.0
# New York               14000.0  146427.247706  590000.0
# Wisconsin                  1.0  145806.888889  920000.0
# District of Columbia   59000.0  140514.285714  200000.0
# Washington                72.0  139922.904110  340000.0
# Alabama                52000.0  138000.000000  350000.0
# Ohio                   42000.0  137066.666667  954000.0
# New Jersey             67500.0  126153.846154  192000.0
# [2021 2022 2023]

# %% [markdown]
# ## Bonus
#
# Clearly, we do not have enough data to produce useful figures for the level of specificity you’ve now reached. What do you notice about Delaware and West Virginia?
#
# Let’s back out a bit and return to `df_salary` (which was the loaded data with renamed columns but *sans* filtering).

# %% [markdown]
# ### Bonus #0
#
# Apply the same steps as before to `df_salary`, but do not filter for any specific industry. Do perform the other data cleaning stuff, and get to a point where you can generate the minimum, mean, and maximum by state.

# %%
df_us = df_salary_usd[df_salary_usd["country"].str.strip().str.lower() == "us"][["state", "salary"]].copy()
df_us = df_us.assign(state=df_us["state"].str.split(r",\s*")).explode("state")
df_us["state"] = df_us["state"].str.strip()
grouped = df_us.groupby("state")["salary"]
stats = grouped.agg(["min", "mean", "max"])
state_salary_stats = stats.sort_values("mean", ascending=False)
print(state_salary_stats.head(10))
# Out:
#                            min           mean        max
# state
# Florida                28800.0  210711.000000  2600000.0
# Delaware              169000.0  169000.000000   169000.0
# Connecticut            68000.0  161610.000000   270000.0
# California                 0.0  153736.303867   520000.0
# New York               14000.0  146427.247706   590000.0
# Wisconsin                  1.0  145806.888889   920000.0
# District of Columbia   59000.0  140514.285714   200000.0
# Washington                72.0  139398.945946   340000.0
# Ohio                   42000.0  137066.666667   954000.0
# New Jersey             67500.0  126153.846154   192000.0

# %% [markdown]
# ### Bonus #1
#
# This time, format the table output nicely (*$12,345.00*) without modifying the values in the `DataFrame`. That is, `df_salary` should be identical before versus after running your code.
#
# (*Hint: if you run into an error about `jinja2` perhaps you need to `pip install` something.*)

# %%
#according to documentation, this will print salary in the following format $12,345.00
display(state_salary_stats.style.format("${:,.2f}"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_7c3ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c3ef_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_7c3ef_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_7c3ef_level0_col2" class="col_heading level0 col2" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >state</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c3ef_level0_row0" class="row_heading level0 row0" >Florida</th>
#       <td id="T_7c3ef_row0_col0" class="data row0 col0" >$28,800.00</td>
#       <td id="T_7c3ef_row0_col1" class="data row0 col1" >$210,711.00</td>
#       <td id="T_7c3ef_row0_col2" class="data row0 col2" >$2,600,000.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ### Bonus #2
#
# Filter out the non-single-states (e.g., `'California, Colorado'`) in the most elegant way possible (i.e., *not* by blacklisting all the bad values).

# %%
#my dataset already shows this as complete because of the following:
#df_us = df_salary_usd[df_salary_usd["country"].str.strip().str.lower() == "us"][["state", "salary"]].copy()
#df_us = df_us.assign(state=df_us["state"].str.split(r",\s*")).explode("state")
#df_us["state"] = df_us["state"].str.strip()

# %% [markdown]
# ### Bonus #3
#
# Show the quantiles instead of just minimum, mean, and maximum―say 0%, 5%, 25%, 50%, 75%, 95%, and 100%. Outliers may be deceiving.
#
# Sort by whatever interests you―like say the *50th* percentile.
#
# And throw in a count by state too. It would be interesting to know how many data points contribute to the figures for each state. (*Hint: your nice formatting from Bonus #1 might not work this time around.* 😜)

# %%
df_us = df_us.copy()
df_us["salary"] = pd.to_numeric(df_us["salary"], errors="coerce")
df_us = df_us.dropna(subset=["salary"])

qs = [0, 0.25, 0.50, 0.75, 1.00]
quantiles = df_us.groupby("state")["salary"].quantile(qs).unstack()
count_by_state = df_us.groupby("state")["salary"].size().rename("count")

state_quantiles = (quantiles.join(count_by_state).sort_values(0.50, ascending=False))
print(state_quantiles.head(10))
# Out:
#                            0.0      0.25       0.5      0.75       1.0  count
# state
# Delaware              169000.0  169000.0  169000.0  169000.0  169000.0      1
# California                 0.0  110000.0  151000.0  185000.0  520000.0    181
# Washington                72.0  100287.5  143500.0  164463.5  340000.0     74
# New York               14000.0  110000.0  140000.0  180000.0  590000.0    109
# District of Columbia   59000.0  112400.0  140000.0  176750.0  200000.0     14
# New Jersey             67500.0  100000.0  133000.0  140000.0  192000.0     13
# Montana                65000.0   96500.0  128000.0  136500.0  145000.0      3
# Connecticut            68000.0  112550.0  127500.0  230000.0  270000.0      5
# Illinois               36000.0   84500.0  127000.0  140500.0  228800.0     35
# Nevada                107100.0  115825.0  124550.0  133275.0  142000.0      2
